# %%
# %config IPCompleter.greedy=True
# %matplotlib inline

# %%
import pandas as pd

pd.read_json("../resources/data/432909.json.gz", orient = "values", compression = "gzip")
# Out:
#               id  resource_state                       external_id  \
# 0     2888389244               2            garmin_push_4281086985
# 1     2881403465               2            garmin_push_4272533889
# 2     2880416494               2            garmin_push_4271265083
# 3     2886007699               2            garmin_push_4278257253
# 4     2876581000               2            garmin_push_4266548930
# ...          ...             ...                               ...
# 2332     8860606               2  d127bc9bfa556318aeb9ba559f286bd7
# 2333     8427655               2  499b3c23dd096ff0a638a07eaa23461c
# 2334     8250981               2  a1c7e694286d47c4809f47abf7c461da
# 2335     7692273               2  8edce49d53b5aa984a5ff4131400ecf9
# 2336     7635160               2  38d48c56274163c213e58e6ddba836d2
#
#          upload_id                                            athlete  \
# 0     3.068389e+09  {'id': 432909, 'resource_state': 1, 'type': 'A...
# ...
